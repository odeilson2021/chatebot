# %%
# ✅ Instala dependências essenciais
# !pip install pygit2==1.15.1 -q

# ✅ Verifica se já foi clonado antes de clonar novamente
import os

# %cd /content

if not os.path.exists('/content/Fooocus'):
    print("📦 Clonando repositório Fooocus...")
    # !git clone https://github.com/lllyasviel/Fooocus.git
else:
    print("✅ Repositório já existe, atualizando...")
    # %cd /content/Fooocus
    # !git pull

# %cd /content/Fooocus

# ✅ Instala requisitos do Fooocus antes de executar
print("📦 Instalando requisitos...")
# !pip install -r requirements_versions.txt -q

# ✅ Executa com flags adicionais para maior estabilidade
print("🚀 Iniciando Fooocus...")
# !python entry_with_update.py --share --always-high-vram
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 37.4 MB/s eta 0:00:00
# /content
# 📦 Clonando repositório Fooocus...
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 28.63 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# /content/Fooocus
# 📦 Instalando requisitos...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 4.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
